# %% [markdown]
# 1 Crie um programa que recebe uma lista de números e
# - retorne o maior elemento
# - retorne a soma dos elementos
# - retorne o número de ocorrências do primeiro elemento da lista
# - retorne a média dos elementos
# - retorne o valor mais próximo da média dos elementos
# - retorne a soma dos elementos com valor negativo
# - retorne a quantidade de vizinhos iguais

# %%
from numpy import median 

lista=[] 
count = 0
igual = 0
for i in range (5):
    x=int(input("Digite número: %s " %i)) 
    lista.insert(i,x)    

    if count == x: igual += 1  
        
    count = x
    
    i+=1
primeiro = lista[0]
media = median(lista) 
for i in range(5):
    x=lista[i]
    if x <= media and x > i - 1: print("%s " %x)
    
print(lista)
print("O maior elemento: %s " %(max(lista)))
print("Soma dos elementos: %s " %(sum(lista)))
print("O número: %s " %primeiro + " apereceu %s " %lista.count(primeiro) + "vez(es).")
print("Média: %s " %media)
print("Próximo da média: %s " %x)
print("Soma de negativos: %s " %(sum(i for i in lista if i < 0)))
print("Vizinhos iguais: %s " %(igual))
# Out:
# Digite número: 0 5
# Digite número: 1 5
# Digite número: 2 6
# Digite número: 3 6
# Digite número: 4 1
# [5, 5, 6, 6, 1]
# O maior elemento: 6
# Soma dos elementos: 23
# O número: 5  apereceu 2 vez(es).
# Média: 5.0
# Próximo da média: 1
# Soma de negativos: 0
# Vizinhos iguais: 2

# %% [markdown]
# Faça um programa que receba duas listas e retorne True se são
# iguais ou False caso contrario.
# Duas listas são iguais se possuem os mesmos valores e na mesma
# ordem.

# %%
lista1 = []
lista2 = []

for i in range (5):
    x=int(input("Digite número para lista 1: %s " %i)) 
    lista1.insert(i,x)    
    
    
    i+=1
    

for i in range(5):
    x=int(input("Digite número para lista 2: %s " %i))
    lista2.insert(i, x)

    i+=1
    
        
print("São iguais: %s " %(lista1 == lista2))
# Out:
# Digite número para lista 1: 0 0
# Digite número para lista 1: 1 1
# Digite número para lista 1: 2 2
# Digite número para lista 1: 3 3
# Digite número para lista 1: 4 4
# Digite número para lista 2: 0 0
# Digite número para lista 2: 1 1
# Digite número para lista 2: 2 2
# Digite número para lista 2: 3 3
# Digite número para lista 2: 4 4
# São iguais: True

# %% [markdown]
# Faça um programa que receba duas listas e retorne True se são
# iguais ou False caso contrario.
# Duas listas são iguais se possuem os mesmos valores e na mesma
# ordem.

# %%
lista1 = []
lista2 = []

for i in range (5):
    x=int(input("Digite número para lista 1: %s " %i)) 
    lista1.insert(i,x)    
    
    
    i+=1
    

for i in range(5):
    x=int(input("Digite número para lista 2: %s " %i))
    lista2.insert(i, x)

    i+=1
    
lista1.sort()
lista2.sort()
        
print("São iguais: %s " %(lista1 == lista2))
# Out:
# Digite número para lista 1: 0 0
# Digite número para lista 1: 1 1
# Digite número para lista 1: 2 3
# Digite número para lista 1: 3 2
# Digite número para lista 1: 4 4
# Digite número para lista 2: 0 4
# Digite número para lista 2: 1 3
# Digite número para lista 2: 2 2
# Digite número para lista 2: 3 1
# Digite número para lista 2: 4 0
# São iguais: True

# %% [markdown]
# Faça um programa que percorre uma lista com o seguinte
# formato: [['Brasil', 'Italia', [10, 9]], ['Brasil', 'Espanha', [5, 7]],
# ['Italia', 'Espanha', [7,8]]]. Essa lista indica o número de faltas que
# cada time fez em cada jogo. Na lista acima, no jogo entre Brasil e
# Itália, o Brasil fez 10 faltas e a Itália fez 9.
# O programa deve imprimir na tela:
# - o total de faltas do campeonato
# - o time que fez mais faltas
# - o time que fez menos faltas

# %%
campeonato = [['Brasil', 'Italia', [20, 9]], ['Brasil', 'Espanha', [5, 7]], ['Italia', 'Espanha', [7, 8]]]

jogo1 = ['Brasil', 'Italia', [20, 9]]
jogo2 = ['Brasil', 'Espanha', [5, 7]]
jogo3 = ['Italia', 'Espanha', [7, 8]]
    
faltas = []
    
for x in campeonato:
    faltas.append(sum(x[2]))
    

brasil = 0
italia = 0
espanha = 0
    
print('Total de faltas no campeonato: %s '%sum(faltas))

#total de faltas
for j in jogo1, jogo2, jogo3:
    if(j[0] == 'Brasil' or j[1] == 'Brasil'):
        brasil +=(j[2][0])
    if(j[0]=='Italia' or j[1]=='Italia'):
        aux = (jogo1[2][1])
        italia = (jogo3[2][0])
        italia = aux + italia
    if (j[0]=='Espanha' or j[1]=='Espanha'):
        espanha +=(j[2][1])

#time com mais faltas
if (brasil > espanha and brasil > italia):
    print ("Brasil: %s" %(brasil))
if (italia > espanha and italia > brasil):
    print ("Italia: %s" %(italia))
if ( espanha > brasil and espanha > italia):
    print ("Espanha: %s" %(espanha))

#time com menos faltas
if (brasil < espanha and brasil < italia):
    print ("Brasil: %s" %(faltas_Brasil))
if (italia < espanha and italia < brasil):
    print ("Italia: %s" %(italia))
if ( espanha < brasil and espanha < italia):
    print ("Espanha: %s" %(espanha))
# Out:
# Total de faltas no campeonato: 56
# Brasil: 25
# Espanha: 15

# %% [markdown]
# Escreva um programa que conta a quantidade de vogais em uma
# string e armazena tal quantidade em um dicionário, onde a chave é
# a vogal considerada.

# %%
frase = input("Digite a frase").upper()

dic={}

if ('A' in frase):
    dic['A'] = frase.count("A")
elif('E' in frase):
    dic['E'] = frase.count("E")
elif('I' in frase):
    dic['I'] = frase.count("I")
elif('O' in frase):
    dic['O'] = frase.count("O")
elif('U' in frase):
    dic['U'] = frase.count("U")
print(dic)

# %% [markdown]
# Escreva um programa que lê̂ duas notas de vários alunos e
# armazena tais notas em um dicionário, onde a chave é o nome do
# aluno. A entrada de dados deve terminar quando for lida uma string
# vazia como nome. Escreva uma função que retorna a média do
# aluno, dado seu nome.

# %%
dic = {}

while True:
    aluno = input("Nome do aluno: ")
    
    if aluno == '': break
        
    lista = []
    for i in range(2):
        nota = int(input("Nota do aluno: %s " %aluno))
        lista.insert(i, nota)    
        
    dic[aluno] = lista
    
while True:
    
    nota = input("Insira o nome do Aluno: ")
    if nota == '': break
        
    print ((dic[nota][0] + dic[nota][1])/2)
# Out:
# Nome do aluno: Renan
# Nota do aluno: Renan 10
# Nota do aluno: Renan 10
# Nome do aluno: Gui
# Nota do aluno: Gui 6
# Nota do aluno: Gui 8
# Nome do aluno:
# Insira o nome do Aluno: Gui
# 7.0
# Insira o nome do Aluno: Renan
# 10.0
# Insira o nome do Aluno:

# %% [markdown]
# Uma pista de Kart permite 10 voltas para cada um de 6
# corredores. Escreva um programa que leia todos os tempos em
# segundos e os guarde em um dicionário, onde a chave é o nome do
# corredor. Ao fnal diga de quem foi a melhor volta da prova e em
# que volta; e ainda a classifcação fnal em ordem (1o o campeão). O
# campeão é o que tem a menor média de tempos.

# %%
import sys

menor_tempo = sys.maxsize
corredor_menor_tempo = ""
volta = ""
kart = {}
final = {}

corredor1 = {'José': {
    'Voltas': {'Volta 1': 300, 'Volta 2': 302, 'Volta 3': 304, 'Volta 4': 306, 'Volta 5': 308, 'Volta 6': 310,
               'Volta 7': 245, 'Volta 8': 365, 'Volta 9': 248, 'Volta 10': 300}}}
corredor2 = {'João': {
    'Voltas': {'Volta 1': 290, 'Volta 2': 300, 'Volta 3': 310, 'Volta 4': 315, 'Volta 5': 306, 'Volta 6': 300,
               'Volta 7': 220, 'Volta 8': 241, 'Volta 9': 254, 'Volta 10': 285}}}
corredor3 = {'Jefferson': {
    'Voltas': {'Volta 1': 210, 'Volta 2': 100, 'Volta 3': 190, 'Volta 4': 198, 'Volta 5': 200, 'Volta 6': 250,
               'Volta 7': 140, 'Volta 8': 257, 'Volta 9': 236, 'Volta 10': 247}}}
corredor4 = {'Cristian': {
    'Voltas': {'Volta 1': 300, 'Volta 2': 284, 'Volta 3': 265, 'Volta 4': 285, 'Volta 5': 236, 'Volta 6': 245,
               'Volta 7': 269, 'Volta 8': 258, 'Volta 9': 248, 'Volta 10': 268}}}
corredor5 = {'Kleber': {
    'Voltas': {'Volta 1': 210, 'Volta 2': 240, 'Volta 3': 362, 'Volta 4': 128, 'Volta 5': 254, 'Volta 6': 298,
               'Volta 7': 158, 'Volta 8': 351, 'Volta 9': 354, 'Volta 10': 254}}}
corredor6 = {'Carlos': {
    'Voltas': {'Volta 1': 154, 'Volta 2': 365, 'Volta 3': 285, 'Volta 4': 147, 'Volta 5': 356, 'Volta 6': 422,
               'Volta 7': 285, 'Volta 8': 365, 'Volta 9': 254, 'Volta 10': 254}}}

#Aqui, atualiza o dicionário Kart com as informações
kart.update(corredor1)
kart.update(corredor2)
kart.update(corredor3)
kart.update(corredor4)
kart.update(corredor5)
kart.update(corredor6)


for chave, valor in kart.items():
    if menor_tempo > min(valor['Voltas'].values()):
        menor_tempo = min(valor['Voltas'].values())
        corredor_menor_tempo = chave
        volta = min(valor['Voltas'], key=valor['Voltas'].get)



#Aqui, calculo a média
def media(valores, tamanho):
    return (sum(valores) / tamanho)


for chave, valor in kart.items():
    tempo_medio = media(valor['Voltas'].values(), len(valor['Voltas'].values()))
    final.update({chave: tempo_medio})

classificacao_final = sorted(final.items(), key=lambda elem: elem[1])

print(
    "A melhor volta da corrida foi feita por: %s na %s em %ss" % (corredor_menor_tempo, volta, menor_tempo))
print("Classificação final:")
i = 1
for chave, valor in classificacao_final:
    print("%s Lugar: %s com tempo médio de %ss." % (i, chave, valor))
    i = i + 1
# Out:
# A melhor volta da corrida foi feita por: Jefferson na Volta 2 em 100s
# Classificação final:
# 1 Lugar: Jefferson com tempo médio de 202.8s.
# 2 Lugar: Kleber com tempo médio de 260.9s.
# 3 Lugar: Cristian com tempo médio de 265.8s.
# 4 Lugar: João com tempo médio de 282.1s.
# 5 Lugar: Carlos com tempo médio de 288.7s.
# 6 Lugar: José com tempo médio de 298.8s.

# %% [markdown]
# Escreva um programa para armazenar uma agenda de telefones
# em um dicionário. Cada pessoa pode ter um ou mais telefones e a
# chave do dicionário é o nome da pessoa. Seu programa deve ter as
# seguintes funções:
# incluirNovoNome – essa função acrescenta um novo nome na
# agenda, com um ou mais telefones. Ela deve receber como
# argumentos o nome e os telefones.
# incluirTelefone – essa função acrescenta um telefone em um nome
# existente na agenda. Caso o nome não exista na agenda, você̂ deve
# perguntar se a pessoa deseja inclui-lo. Caso a resposta seja
# afrmativa, use a função anterior para incluir o novo nome.
# excluirTelefone – essa função exclui um telefone de uma pessoa
# que já está na agenda. Se a pessoa tiver apenas um telefone, ela
# deve ser excluída da agenda.
# excluirNome – essa função exclui uma pessoa da agenda.
# consultarTelefone – essa função retorna os telefones de uma
# pessoa na agenda.

# %%
#função para adicionar um novo nome e telefone
def novo_nome(nome, telefone):
    agenda[nome] = telefone

#Apenas telefone para um nome existente
def novo_telefone(nome,telefone):
    agenda[nome].append(telefone)


def excluir_telefone(nome,index):
    agenda[nome].pop(index)
    if len(agenda[nome]) == 0:
        excluir_nome(nome)


def excluir_nome(nome):
    agenda.pop(nome)

agenda = {}

print("Opções")
print("Adicionar Nome e Telefone -> 1")
print("Adicionar telefone -> 2")
print("Excluir Nome -> 3")
print("Excluir telefone -> 4")
print("Sair -> 0")
opcao = -1
while(opcao != 0):

    opcao = int(input("Digite a Opção Desejada: "))

    if(opcao == 1):
        nome = input("Digite o nome do contato: ")
        telefones = []
        tel = -1
        while(tel != "0"):

            tel = input("Digite o telefone")
            telefones.append(tel)

        novo_nome(nome, telefones)

    elif opcao == 2:
        nome = input("Digite o nome: ")

        if nome not in agenda:
    
            incluir = input("Esse nome ainda não consta na agenda, deseja incluí-lo ? - S/N")
            if incluir == "S":
        
                nome = input("Digite o nome: ")
                telefones = []
                tel = -1
                while (tel != "0"):
                    tel = input("Digite o telefone: ")
                    telefones.append(tel)
                novo_nome(nome, telefones)
        else:
            tel = -1
            while (tel != 0):
        
                tel = input("Digite o telefone")
                if(tel != "0"):
                    novo_telefone(nome, tel)
    elif opcao == 3:

        nome = input("Digite o nome: ")
        excluir_nome(nome)
    elif opcao == 4:
    
        nome = input("Digite o nome: ")
        print()
        tel = input("Digite o Telefone: ")
        if tel in agenda[nome]:
            index = agenda[nome].index(tel)
            excluir_telefone(nome,index)

    print(agenda)

# %% [markdown]
# Faça um programa que leia um arquivo texto contendo uma lista
# de endereços IP e gere um outro arquivo, contendo um relatório dos
# endereços IP válidos e inválidos.
# O arquivo de entrada possui o seguinte formato:
# 200.135.80.9
# 192.168.1.1
# 8.35.67.74
# 257.32.4.5
# 85.345.1.2
# 1.2.3.4
# 9.8.234.5
# 192.168.0.256
#
# O arquivo de saída possui o seguinte formato:
# [Endereços válidos:]
# 200.135.80.9
# 192.168.1.1
# 8.35.67.74
# 1.2.3.4
# [Endereços inválidos:]
# 257.32.4.5
# 85.345.1.2
# 9.8.234.5
# 192.168.0.256

# %%
import socket

ipsValidos = []
ipsInvalidos = []

ips = open("ips.txt")
for ip in ips:
    try:
        socket.inet_aton(ip)
        # Validos
        ipsValidos.append(ip)
    except socket.error:
        # Invalidos
        ipsInvalidos.append(ip)
        
ips.close()

saida = open("ipsvalidados.txt", "w+")

saida.write("[Endereços válidos:]\n")
for ip in ipsValidos:
    saida.write(ip)
    
saida.write("[Endereços inválidos:]\n")
for ip in ipsInvalidos:
    saida.write(ip)
    
saida.close()

# %% [markdown]
# A ACME Inc., uma empresa de 500 funcionários, está tendo
# problemas de espaço em disco no seu servidor de arquivos. Para
# tentar resolver este problema, o Administrador de Rede precisa
# saber qual o espaço ocupado pelos usuários, e identifcar os
# usuários com maior espaço ocupado. Através de um programa,
# baixado da Internet, ele conseguiu gerar o seguinte arquivo,
# chamado "usuarios.txt":
# alexandre 456123789
# anderson 1245698456
# antonio 123456456
# carlos 91257581
# cesar 987458
# rosemary 789456125
#
# Neste arquivo, o nome do usuário possui 15 caracteres. A partir
# deste arquivo, você deve criar um programa que gere um relatório,
# chamado "relatório.txt", no seguinte formato:
# ACME Inc. Uso do espaço em disco pelos usuários
#
# --------------------------------------------------------------
# ----------
# Nr. Usuário Espaço utilizado % do uso
# 1 alexandre 434,99 MB 16,85%
# 2 anderson 1187,99 MB 46,02%
# 3 antonio 117,73 MB 4,56%
# 4 carlos 87,03 MB 3,37%
# 5 cesar 0,94 MB 0,04%
# 6 rosemary 752,88 MB 29,16%
# Espaço total ocupado: 2581,57 MB
# Espaço médio ocupado: 430,26 MB
# O arquivo de entrada deve ser lido uma única vez, e os dados
# armazenados em memória, caso sejam necessários, de forma a
# agilizar a execução do programa. A conversão da espaço ocupado
# em disco, de bytes para megabytes deverá ser feita através de uma
# função separada, que será chamada pelo programa principal. O
# cálculo do percentual de uso também deverá ser feito através de
# uma função, que será chamada pelo programa principal.

# %%
def to_MB(tamanho_em_bytes):
    tamanho_em_bytes = float(tamanho_em_bytes)
    return (float(tamanho_em_bytes / (1024 * 1024)))


def percentual_por_usuario(lista, total):
    percentual = (lista[3] / total) * 100
    # percentual = "{0:.2f}".format(percentual)
    lista.insert((len(cada_usuario)), percentual)


def espaco_medio_ocupado(lista, total):
    media = 0
    elementos = len(lista)
    media = (total) / (elementos + 1)
    # media = "{0:.2f}".format(media)
    return media


# MAIN
usuarios = []
posicao = 1
total = media = 0
with open("usuarios.txt", "r") as arquivo:
    valor = 0
    for linha in arquivo:
        usuarios.append(linha.split())

    for cada_usuario in usuarios:
        cada_usuario.insert(0, posicao)
        valor = to_MB(float(cada_usuario[2]))
        total += valor
        cada_usuario.insert((len(cada_usuario)), valor)
        posicao += 1

    for cada_usuario in usuarios:
        percentual_por_usuario(cada_usuario, total)

media = espaco_medio_ocupado(cada_usuario, total)

with open("relatorio.txt", "w") as arquivo:
    arquivo.write("ACME Inc.               Uso do espaço em disco pelos usuários.\n")
    arquivo.write("--------------------------------------------------------------\n")
    arquivo.write("Nr.\tUsuário        \tEspaço utilizado\t% do uso\n\n")

    for cada_usuario in usuarios:
        percentagem = "{0:.2f}".format(round(cada_usuario[3], 2))
        arquivo.write(str(cada_usuario[0]) + '\t' + "{:<15}".format(cada_usuario[1]) + '\t' + "{:<16}".format(
            percentagem) + 'MB' + '\t' + "{0:.2f}".format(cada_usuario[4]) + '%' + '\n')

    arquivo.write('\n\nEspaço Total Ocupado: ' + "{0:.2f}".format(total) + ' MB')
    arquivo.write('\n\nEspaço médio Ocupado: ' + "{0:.2f}".format(media) + ' MB')
    arquivo.close()

with open("relatorio.txt", "r") as arquivo:
    print(arquivo.read())
